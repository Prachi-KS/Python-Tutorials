# %%
import numpy as np
import pandas as pd

# %%
annual=pd.read_csv("annual.csv")
annual.head()
annual.describe()
# Out:
#                Year
# count  37080.000000
# mean    2016.495200
# std        2.301976
# min     1978.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
head1=annual.head()
head1.columns
#type(head1)
head1.shape
head1.describe()
head1.isnull()
head1.dropna()
# Out:
#    Year Industry_Agg Industry_code_NZSIOC   Industry_name               Units  \
# 0  2020      Level 1                99999  All industries  Dollars (millions)
# 2  2020      Level 1                99999  All industries  Dollars (millions)
# 3  2020      Level 1                99999  All industries  Dollars (millions)
# 4  2016      Level 1                99999  All industries  Dollars (millions)
#
#   Variable_code                      Variable_name      Variable_category  \
# 0           H01                       Total income  Financial performance
# 2           H05  Interest, dividends and donations  Financial performance
# 3           H07               Non-operating income  Financial performance
# 4           H08                  Total expenditure  Financial performance
#
#       Value                             Industry_code_ANZSIC06
# 0  7,33,258  ANZSIC06 divisions A-S (excluding classes K633...
# 2    54,342  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %%
head2.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-106b994c9a7b> in <module>
# ----> 1 head2.nunique()
#
# NameError: name 'head2' is not defined

# %%
head2=annual.loc[0:20,['Value','Variable_name','Year','Variable_category']]
head2.isnull().sum()
#head2['Year'].sum()
head2.describe()
head2.nunique()

# %%
head2['Value'].unique()
head2.shape

# %%
import matplotlib.pyplot as plt
head2.plot(x='Year',y="Variable_name",kind="scatter")

# %%
pip install seaborn

# %%
import seaborn as sns
import numpy as np
sns.set(style='dark')
rs=np.random.RandomState(10)
d=rs.normal(size=100)
sns.histplot(d,kde=True,color='r')

# %%
data=sns.load_dataset('fmri')
data.head()
sns.lineplot(x='timepoint',
            y='signal',
             hue='subject',
             style='event',
             data=data
)

# %%
###############fifa data EDA####################
import numpy as np
import pandas as pd
fifa=pd.read_csv('fifa.csv')
fifa

# %%
#fifa=fifa.head()
fifa
fifa['nationality'].value_counts()

# %%
a=fifa['nationality'].value_counts()[0:5]
a=list(a)
type(a)
a

# %%
b=fifa['nationality'].value_counts()[0:5].keys()
type(b)
b=list(b)
b

# %%
from matplotlib import pyplot as plt
plt.plot()

# %%
plt.bar(b,a,color=['red','yellow','b','g','black'])
plt.show()

# %%
height=fifa[['height_cm','short_name']]
height=height.sort_values(by=['height_cm'],ascending=False)
height[0:10]
type(height)
height1=height['height_cm'].value_counts()
type(height1)

# %%
fifa1=fifa['height_cm']
f=fifa1.value_counts()[0:10]
f.keys()
names=fifa['short_name']
names.value_counts()[0:10].keys()

# %%
plt.figure(figsize=(10,5))
plt.bar(list(height['short_name'].value_counts()[0:10].keys()),list(height['height_cm'].value_counts()[0:10]),color=['r','b','b','r','g'])
plt.show

# %%
import seaborn as sns
import numpy as nd
L=[12,45,30,56,34,7,3]
arr1=nd.array(L)
arr1
type(arr1)
arr1[arr1>10]=11
arr1
# Out:
# array([11, 11, 11, 11, 11,  7,  3])

# %%
fifa.shape
# Out:
# (18944, 106)

# %%
age=fifa[fifa['age']>35][0:10]
age['age'].describe()
age
# Out:
#      sofifa_id                                         player_url  \
# 168      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 239       1179  https://sofifa.com/player/1179/gianluigi-buffo...
# 316         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 317     120533  https://sofifa.com/player/120533/kepler-lavera...
# 320     156616  https://sofifa.com/player/156616/franck-ribery...
# 429       9014  https://sofifa.com/player/9014/arjen-robben/21...
# 430      45186  https://sofifa.com/player/45186/joaquin-sanche...
# 435     159261  https://sofifa.com/player/159261/fabio-quaglia...
# 447     178372  https://sofifa.com/player/178372/branislav-iva...
# 495     245299  https://sofifa.com/player/245299/jaime-nicolas...
#
#           short_name                        long_name  age         dob  \
# 168   Z. Ibrahimović               Zlatan Ibrahimović   38  1981-10-03
# 239        G. Buffon                 Gianluigi Buffon   42  1978-01-28
# ...

# %%
sns.boxplot(x=age['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
first=age['age'].quantile(.25)
third=age['age'].quantile(.75)
print(first,third)
# Out:
# 36.0 37.75

# %%
QR=third-first
# Out:
# 1.75

# %%
new_boundry=third+3*QR
new_boundry
age.drop(age[age['age']>new_boundry].index,axis=0,inplace=True)
age
# Out:
#      sofifa_id                                         player_url  \
# 168      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 316         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 317     120533  https://sofifa.com/player/120533/kepler-lavera...
# 320     156616  https://sofifa.com/player/156616/franck-ribery...
# 429       9014  https://sofifa.com/player/9014/arjen-robben/21...
# 430      45186  https://sofifa.com/player/45186/joaquin-sanche...
# 435     159261  https://sofifa.com/player/159261/fabio-quaglia...
# 447     178372  https://sofifa.com/player/178372/branislav-iva...
# 495     245299  https://sofifa.com/player/245299/jaime-nicolas...
#
#           short_name                        long_name  age         dob  \
# 168   Z. Ibrahimović               Zlatan Ibrahimović   38  1981-10-03
# 316          Iniesta             Andrés Iniesta Luján   36  1984-05-11
# 317             Pepe  Kléper Laveran de Lima Ferreira   37  1983-02-26
# ...

# %%
sns.boxplot(x=age['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
#age[age['age']].index
age[age['age']>35]
# Out:
#      sofifa_id                                         player_url  \
# 168      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 239       1179  https://sofifa.com/player/1179/gianluigi-buffo...
# 316         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 317     120533  https://sofifa.com/player/120533/kepler-lavera...
# 320     156616  https://sofifa.com/player/156616/franck-ribery...
# 429       9014  https://sofifa.com/player/9014/arjen-robben/21...
# 430      45186  https://sofifa.com/player/45186/joaquin-sanche...
# 435     159261  https://sofifa.com/player/159261/fabio-quaglia...
# 447     178372  https://sofifa.com/player/178372/branislav-iva...
# 495     245299  https://sofifa.com/player/245299/jaime-nicolas...
#
#           short_name                        long_name  age         dob  \
# 168   Z. Ibrahimović               Zlatan Ibrahimović   38  1981-10-03
# 239        G. Buffon                 Gianluigi Buffon   42  1978-01-28
# ...

# %%
age[age['age']>41].index
# Out:
# Int64Index([239], dtype='int64')

# %%
age.drop(age[age['age']>41].index,axis=0,inplace=True)
# Out:
#      sofifa_id                                         player_url  \
# 168      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 316         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 317     120533  https://sofifa.com/player/120533/kepler-lavera...
# 320     156616  https://sofifa.com/player/156616/franck-ribery...
# 429       9014  https://sofifa.com/player/9014/arjen-robben/21...
# 430      45186  https://sofifa.com/player/45186/joaquin-sanche...
# 435     159261  https://sofifa.com/player/159261/fabio-quaglia...
# 447     178372  https://sofifa.com/player/178372/branislav-iva...
# 495     245299  https://sofifa.com/player/245299/jaime-nicolas...
#
#           short_name                        long_name  age         dob  \
# 168   Z. Ibrahimović               Zlatan Ibrahimović   38  1981-10-03
# 316          Iniesta             Andrés Iniesta Luján   36  1984-05-11
# 317             Pepe  Kléper Laveran de Lima Ferreira   37  1983-02-26
# ...

# %%
sns.boxplot(x=age['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
wage=fifa[fifa['wage_eur']>80000][0:10]
wage.shape
# Out:
# (10, 106)

# %%
wage['wage_eur'].describe()
# Out:
# count        10.000000
# mean     257500.000000
# std      126869.355375
# min      125000.000000
# 25%      172500.000000
# 50%      230000.000000
# 75%      267500.000000
# max      560000.000000
# Name: wage_eur, dtype: float64

# %%
sns.boxplot(x=wage['wage_eur'])
# Out:
# <AxesSubplot:xlabel='wage_eur'>

# %%
wage['wage_eur']
# Out:
# 0    560000
# 1    220000
# 2    125000
# 3    240000
# 4    270000
# 5    370000
# 6    160000
# 7    260000
# 8    210000
# 9    160000
# Name: wage_eur, dtype: int64

# %%
f=wage['wage_eur'].quantile(.25)
t=wage['wage_eur'].quantile(.75)
Qr=t-f
new=t+Qr*3
new
# Out:
# 552500.0

# %%
wage.drop(wage[wage['wage_eur']>new].index,axis=0,inplace=True)

# %%
sns.boxplot(x=wage['wage_eur'])
# Out:
# <AxesSubplot:xlabel='wage_eur'>

# %%
#name=wage['short_name'].value_counts().keys()
list(name)
name
# Out:
# Index(['Neymar Jr', 'Alisson', 'K. Mbappé', 'K. De Bruyne',
#        'Cristiano Ronaldo', 'L. Messi', 'M. ter Stegen', 'J. Oblak',
#        'R. Lewandowski', 'V. van Dijk'],
#       dtype='object')
